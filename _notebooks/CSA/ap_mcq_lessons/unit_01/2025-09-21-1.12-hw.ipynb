# %% [raw]
# ---
# layout: post
# toc: true
# title: 1.12 Homework
# menu: nav/csa_units/csaunit1.html
# permalink: /csa/unit_01/1_12/homework
# author: Trevor, Kush, Elliot, Aranya, Travis, Alex
# ---

# %% [markdown]
# # 1.12 Homework
#
# Apply what you learned about classes, objects, and reference variables by modeling students in a classroom.
#
# <div class="callout callout-objectives" markdown="1">
# <h4>Objectives</h4>
#
# - Design a class with multiple instance variables
# - Create several objects from the same class
# - Create a second reference variable that points to an existing object
# - Observe how changes through one reference are visible through another
#
# </div>
#
# <div class="lesson-wrap" markdown="1">
#
# ## Scenario
#
# It's your first day of class when Mr. Mortenson asks you to identify all the students and list some characteristics about them. Create a class to use as a template to create student objects and create 3 imaginary students.
#
# <div class="callout callout-homework" markdown="1">
# <h4>Homework Hack 1</h4>
#
# 1. **Create a class** with instance variables:
#    - `String name`
#    - `int grade`
#    - `int pets`
#    - `int siblings`
#    - `MAKE YOUR OWN`
#
# 2. **In `main`:**
#    - Create three student objects.
#
# </div>

# %% [markdown]
# **Hint:** Start small. Write the class with just `name` and `grade`, make one student, and print their name. Once that runs, add the rest of the fields and the other two students.

# %%
//Code Here

# %% [markdown]
# ## New Scenario
#
# You find out that one of the students that you created an object for goes by a nickname. Using your knowledge of reference variables, create another object that references back to the same student.
#
# <div class="callout callout-homework" markdown="1">
# <h4>Homework Hack 2</h4>
#
# 1. **Use your previous code.**
#
# 2. **In `main`:**
#    - Create a reference variable with a different name that points to the same student.
#    - Output the instance attributes of this student.
#
# </div>
#
# **Quick Check before you code:** if you write `Student nickname = student1;` and then change `nickname.name`, does `student1.name` change too? Why?
#
# <details>
# <summary>Show answer</summary>
#
# Yes. `nickname` and `student1` are two variable names pointing at the exact same object in memory. There is only one `Student` here, so a change made through either name shows up when you read it back through the other name.
# </details>
#
# </div>

# %%
// Code Here
