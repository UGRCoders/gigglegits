// %% [markdown]
// ---
// layout: post
// toc: true
// title: Unit 1 Quiz
// menu: nav/csa_units/csaunit1.html
// permalink: /csa/unit_01/quiz
// ---

// %% [markdown]
// # Unit 1 Quiz
//
// Check your understanding of Unit 1: variable naming, primitive types, division behavior, memory (stack vs heap), static and instance methods, the Math class, and String methods.
//
// <div class="callout callout-objectives">
// <h4>Objectives</h4>
//
// - Apply Java variable naming conventions
// - Predict the result of integer versus floating point division
// - Identify Java's primitive data types, including char and numeric types
// - Distinguish primitive types from reference types and explain stack versus heap storage
// - Tell static (class) methods apart from instance methods, and know which calls are legal
// - Manipulate `Math.random()` to produce a value in a specific range
// - Recognize the common compile-time and runtime errors around calling instance methods
// - Use core `String` methods like `substring` and `compareTo`
// - Design a class with instance variables, a constructor, and a static field
//
// </div>
//
// <style>
// .lesson-wrap { font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; color:#1e293b; line-height:1.65; }
// .lesson-wrap h2 { color:#0f172a; border-bottom:2px solid #e2e8f0; padding-bottom:6px; margin-top:1.8em; }
// .lesson-wrap h3 { color:#1e293b; margin-top:1.4em; }
// .callout { border-radius:10px; padding:16px 20px; margin:16px 0; border:1px solid #e2e8f0; background:#f8fafc; }
// .callout-objectives { background:#eff6ff; border-left:4px solid #2563eb; }
// .callout-objectives h4 { color:#1d4ed8; margin:0 0 8px 0; }
// .callout-hint { background:#fefce8; border-left:4px solid #ca8a04; }
// .callout-hint h4 { color:#a16207; margin:0 0 8px 0; }
// .callout-practice { background:#f0fdf4; border-left:4px solid #16a34a; }
// .callout-practice h4 { color:#15803d; margin:0 0 8px 0; }
// .callout-homework { background:#fdf4ff; border-left:4px solid #9333ea; }
// .callout-homework h4 { color:#7e22ce; margin:0 0 8px 0; }
// .callout-note { background:#f1f5f9; border-left:4px solid #64748b; }
// .callout-note h4 { color:#334155; margin:0 0 8px 0; }
// table { border-collapse:collapse; width:100%; margin:16px 0; }
// th, td { border:1px solid #e2e8f0; padding:10px 14px; text-align:left; }
// th { background:#f1f5f9; color:#0f172a; }
// details { border:1px solid #e2e8f0; border-radius:8px; padding:10px 16px; margin:12px 0; background:#fafafa; }
// details summary { cursor:pointer; font-weight:600; color:#2563eb; }
// details[open] summary { margin-bottom:10px; }
// .btn { display:inline-block; padding:10px 22px; border-radius:8px; border:none; font-weight:600; cursor:pointer; font-size:14px; transition:background .2s,transform .2s; }
// .btn-primary { background:#2563eb; color:#fff; }
// .btn-primary:hover { background:#1d4ed8; }
// .btn-secondary { background:#e2e8f0; color:#1e293b; }
// .btn-secondary:hover { background:#cbd5e1; }
// .pill { display:inline-block; padding:3px 12px; border-radius:999px; background:#eff6ff; color:#1d4ed8; font-size:0.85em; font-weight:600; margin-right:6px; }
// </style>
//
// <div class="lesson-wrap">
//
// ## Variables and Primitive Types

// %% [markdown]
// ### Question 1
//
// Which of the following is a valid declaration of a variable of type int in Java?<br>
// a) int 123variable;<br>
// b) int variable123;<br>
// c) int variable#123;<br>
// d) int variable 123;
//
// <details>
// <summary>Show answer</summary>
//
// b) int variable123;
//
// </details>

// %%
// Q1 Hack: Define variables according to Java naming conventions.
// For instance, is it snake_case, camelCase, or PascalCase?

int variable123 = 123;
System.out.println(variable123);

// %% [markdown]
// ### Question 2
//
// What is the value of the following expression in Java: 5 / 2?<br>
// a) 2.5<br>
// b) 3<br>
// c) 2<br>
// d) 2.0
//
// <details>
// <summary>Show answer</summary>
//
// c) 2
//
// </details>

// %%
// Q2.1 Hack: Show in code difference between integer and floating point division.
// Q2.2 Hack: Show in code the different number types in Java and how they behave.
// Behave means definition and assignment.

// %% [markdown]
// ### Question 3
//
// Which primitive type is used to represent a single character in Java?<br>
// a) char<br>
// b) String<br>
// c) int<br>
// d) byte
//
// <details>
// <summary>Show answer</summary>
//
// a) char
//
// </details>

// %%
// Q3.1 Hack: Show in code all the the non-number Java primitive data types and how they behave.
// Q3.2 Hack: Show in code the String data type and how it behaves.

// %% [markdown]
// ## Classes, References, and Memory
//
// ### Question 4
//
// Answer the following questions based on the code cell:
// * a) What kind of types are person1 and person2?
// * b) Do person1 and person3 point to the same value in memory?
// * c) Is the integer "number" stored in the heap or in the stack?
// * d) Is the value that "person1" points to stored in the heap or in the stack?
//
// <details>
// <summary>Show answer</summary>
//
// a) `person1` and `person2` are reference types (they hold the address of a `Person` object, not the object itself).
//
// b) Yes. `person3 = person1;` copies the reference, not the object, so both variables point to the same `Person` in memory. Changing a field through `person3` would be visible through `person1` too.
//
// c) `number` is a primitive `int`, so it's stored on the stack.
//
// d) The actual `Person` object that `person1` points to lives on the heap. Only the reference itself (the address) is stored on the stack.
//
// </details>

// %%
public class Person {
    String name;
    int age;
    int height;
    String job;

    public Person(String name, int age, int height, String job) {
        this.name = name;
        this.age = age;
        this.height = height;
        this.job = job;
    }
}

public static void main(String[] args) {
    Person person1 = new Person("Carl", 25, 165, "Construction Worker");
    Person person2 = new Person("Adam", 29, 160, "Truck Driver");
    Person person3 = person1;
    int number = 16;
    System.out.println(number);
}
main(null); // This is required in Jupiter Notebook to run the main method.

// %% [markdown]
// ## Static Methods, Math, Instance Calls, and Strings
//
// ### Question 5
//
// Consider the following class:
//
// ```java
// class Robot {
//     String name;
//     static int unitsBuilt = 0;
//
//     public Robot(String name) {
//         this.name = name;
//         unitsBuilt++;
//     }
//
//     public void announce() {
//         System.out.println(name + " reporting for duty.");
//     }
//
//     public static int getUnitsBuilt() {
//         return unitsBuilt;
//     }
// }
// ```
//
// Which line will cause a compiler error?<br>
// a) `Robot.getUnitsBuilt();`<br>
// b) `Robot r = new Robot("R2"); r.announce();`<br>
// c) `Robot.announce();`<br>
// d) `Robot r = new Robot("R2"); r.getUnitsBuilt();`
//
// <details>
// <summary>Show answer</summary>
//
// c) `Robot.announce();`. `announce()` is an instance method, so it needs an object to run on. Calling a method directly on the class name only works for static methods like `getUnitsBuilt()`.
//
// </details>

// %%
// Q5 Hack: Add a second static method to Robot that resets unitsBuilt to 0,
// then call it through the class name (not through an object).

// %% [markdown]
// ### Question 6
//
// What integer range can the following expression produce?
//
// ```java
// int x = (int) (Math.random() * 10) + 5;
// ```
//
// a) 5 to 14, inclusive<br>
// b) 5 to 15, inclusive<br>
// c) 6 to 14, inclusive<br>
// d) 6 to 15, inclusive
//
// <details>
// <summary>Show answer</summary>
//
// a) 5 to 14, inclusive. `Math.random() * 10` gives a value from 0.0 up to (but not including) 10.0, and casting to `int` truncates that down to 0 through 9. Adding 5 shifts the whole range to 5 through 14.
//
// </details>

// %%
// Q6 Hack: Rewrite the formula above so it produces a random int from 1 to 100, inclusive.
int x = (int) (Math.random() * 10) + 5;
System.out.println(x);

// %% [markdown]
// ### Question 7
//
// ```java
// class Cat {
//     String name;
//
//     public Cat(String name) {
//         this.name = name;
//     }
//
//     public void meow() {
//         System.out.println(name + " says meow.");
//     }
// }
//
// Cat c;
// c.meow();
// ```
//
// What happens when this code runs?<br>
// a) It prints "null says meow."<br>
// b) It throws a `NullPointerException`<br>
// c) It does not compile, since `c` is never assigned a `Cat` object<br>
// d) It prints an empty line
//
// <details>
// <summary>Show answer</summary>
//
// c) It does not compile. Local variables in Java must be definitely assigned before use, and `Cat c;` only declares the reference, it never points `c` at an actual object. This is different from calling a method on a reference explicitly set to `null`, which compiles fine but throws a `NullPointerException` at runtime.
//
// </details>

// %%
// Q7 Hack: Fix the Cat example so it compiles and prints "Whiskers says meow."
class Cat {
    String name;
    public Cat(String name) { this.name = name; }
    public void meow() { System.out.println(name + " says meow."); }
}
// Your fix here

// %% [markdown]
// ### Question 8
//
// ```java
// String s = "programming";
// String sub = s.substring(3, 7);
// System.out.println(sub);
// System.out.println(sub.compareTo("gram"));
// ```
//
// What is printed?<br>
// a) `gram` then a value less than 0<br>
// b) `gram` then `0`<br>
// c) `gra` then a value greater than 0<br>
// d) `gramm` then `0`
//
// <details>
// <summary>Show answer</summary>
//
// b) `gram` then `0`. `s.substring(3, 7)` returns the characters from index 3 up to (not including) index 7 of `"programming"`, which spells `"gram"`. Comparing `"gram"` to an identical string with `compareTo` returns `0`.
//
// </details>

// %%
// Q8 Hack: Use indexOf and substring together to pull the word "gram" out of
// a longer string of your own choosing (not "programming").

// %% [markdown]
// ## Synthesis
//
// ### Question 9
//
// (a) Define primitive types and reference types in Java. The application is for banking, where you need to represent customer information.
//
// (b) Add comments for primitive types and reference types. In terms of memory allocation, discuss concepts like instance, stack, and heap where it adds value.
//
// (c) To assist in requirements, here are some required elements:
// - Create multiple customers from the `public class Account`.
// - Consider key class variables that a Bank may require: `name`, `balance`, `accountNumber`.
// - Create a two argument constructor using `name` and `balance`.
// - Consider in constructor how you will create a unique account number using `static int lastAccountNumber`
// - Define a method `calculateInterest` that works with getting and setting `double balance` using `private static double interestRate`.
//
// </div>
