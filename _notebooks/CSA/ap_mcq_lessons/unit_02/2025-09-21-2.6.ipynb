# %% [markdown]
# ---
# layout: post
# toc: true
# title: Comparing Boolean Expressions
# menu: nav/csa_units/csaunit2.html
# permalink: /csa/unit_02/2_6
# ---

# %% [markdown]
# # Comparing Boolean Expressions
#
# Two boolean expressions can look completely different and still always produce the same result. This lesson covers how to prove that with a truth table, and a pair of rules, De Morgan's Laws, for negating compound expressions correctly.
#
# <div class="callout callout-objectives">
# <h4>Objectives</h4>
#
# - Build a truth table to check whether two boolean expressions are equivalent
# - State De Morgan's Laws for negating `&&` and `||` expressions
# - Correctly negate a compound boolean expression
# - Avoid the mistake of distributing `!` without flipping the operator
#
# </div>
#
# <style>
# .lesson-wrap { font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; color:#1e293b; line-height:1.65; }
# .lesson-wrap h2 { color:#0f172a; border-bottom:2px solid #e2e8f0; padding-bottom:6px; margin-top:1.8em; }
# .lesson-wrap h3 { color:#1e293b; margin-top:1.4em; }
# .callout { border-radius:10px; padding:16px 20px; margin:16px 0; border:1px solid #e2e8f0; background:#f8fafc; }
# .callout-objectives { background:#eff6ff; border-left:4px solid #2563eb; }
# .callout-objectives h4 { color:#1d4ed8; margin:0 0 8px 0; }
# .callout-hint { background:#fefce8; border-left:4px solid #ca8a04; }
# .callout-hint h4 { color:#a16207; margin:0 0 8px 0; }
# .callout-practice { background:#f0fdf4; border-left:4px solid #16a34a; }
# .callout-practice h4 { color:#15803d; margin:0 0 8px 0; }
# .callout-homework { background:#fdf4ff; border-left:4px solid #9333ea; }
# .callout-homework h4 { color:#7e22ce; margin:0 0 8px 0; }
# .callout-note { background:#f1f5f9; border-left:4px solid #64748b; }
# .callout-note h4 { color:#334155; margin:0 0 8px 0; }
# table { border-collapse:collapse; width:100%; margin:16px 0; }
# th, td { border:1px solid #e2e8f0; padding:10px 14px; text-align:left; }
# th { background:#f1f5f9; color:#0f172a; }
# details { border:1px solid #e2e8f0; border-radius:8px; padding:10px 16px; margin:12px 0; background:#fafafa; }
# details summary { cursor:pointer; font-weight:600; color:#2563eb; }
# details[open] summary { margin-bottom:10px; }
# .btn { display:inline-block; padding:10px 22px; border-radius:8px; border:none; font-weight:600; cursor:pointer; font-size:14px; transition:background .2s,transform .2s; }
# .btn-primary { background:#2563eb; color:#fff; }
# .btn-primary:hover { background:#1d4ed8; }
# .btn-secondary { background:#e2e8f0; color:#1e293b; }
# .btn-secondary:hover { background:#cbd5e1; }
# .pill { display:inline-block; padding:3px 12px; border-radius:999px; background:#eff6ff; color:#1d4ed8; font-size:0.85em; font-weight:600; margin-right:6px; }
# </style>
#
# <div class="lesson-wrap">
#
# ## Truth Tables
#
# A truth table lists every possible combination of `true`/`false` for each variable in an expression, and shows what the expression evaluates to for each combination. With two variables, `p` and `q`, there are four combinations:
#
# | p | q | p && q | p \|\| q |
# |---|---|---|---|
# | true | true | true | true |
# | true | false | false | true |
# | false | true | false | true |
# | false | false | false | false |
#
# Two expressions are equivalent if their columns match on every row, for every combination of inputs, not just the one you happen to test.

# %% [markdown]
# ## De Morgan's Laws
#
# De Morgan's Laws describe exactly what happens when you negate a compound expression:
#
# - `!(p && q)` is equivalent to `!p || !q`
# - `!(p || q)` is equivalent to `!p && !q`
#
# In words: negating an "and" flips it to an "or" of the negated parts, and negating an "or" flips it to an "and" of the negated parts. You can verify this with a truth table, or check it in code:
#
# ```java
# boolean p = true;
# boolean q = false;
#
# System.out.println(!(p && q));   // true
# System.out.println(!p || !q);    // true, matches !(p && q)
#
# System.out.println(!(p || q));   // false
# System.out.println(!p && !q);    // false, matches !(p || q)
# ```
#
# ## Applying It: Rewriting a Guard Condition
#
# Suppose code only proceeds when a user is both logged in and has a verified email:
#
# ```java
# if (isLoggedIn && isVerified) {
#     System.out.println("Access granted.");
# }
# ```
#
# To write the opposite condition, the one where access should be denied, apply De Morgan's Law rather than guessing:
#
# ```java
# if (!isLoggedIn || !isVerified) {
#     System.out.println("Access denied.");
# }
# ```
#
# <div class="callout callout-hint">
# <h4>Common Mistake: Distributing ! Without Flipping the Operator</h4>
#
# It's tempting to negate `isLoggedIn && isVerified` by just slapping a `!` on each piece and keeping `&&`: `!isLoggedIn && !isVerified`. That is not the same expression. It's only true when both are false, when really you want it true whenever either one fails. The operator has to flip along with each variable, `&&` becomes `||`, exactly as De Morgan's Laws describe.
#
# </div>
#
# <div class="callout callout-practice">
# <h4>Popcorn Hack</h4>
#
# Use De Morgan's Law to write the negation of `inStock || onBackorder`, then check your answer.
#
# <details>
# <summary>Show answer</summary>
#
# `!inStock && !onBackorder`
#
# </details>
#
# </div>
#
# You now have the full toolkit for boolean expressions and if statements. The next lesson moves to repetition, starting with the while loop, which repeats a block of code for as long as a boolean expression like these stays true.
