# %% [markdown]
# ---
# layout: post
# toc: true
# title: Implementing Selection and Iteration Algorithms
# menu: nav/csa_units/csaunit2.html
# permalink: /csa/unit_02/2_9
# ---

# %% [markdown]
# # Implementing Selection and Iteration Algorithms
#
# You now have both halves of this unit's toolkit: if statements and loops. This lesson combines them into a few standard algorithm patterns that show up constantly: finding a maximum, counting matches, and summing values that meet a condition.
#
# <div class="callout callout-objectives">
# <h4>Objectives</h4>
#
# - Write a loop that finds the maximum (or minimum) value in a collection
# - Write a loop that counts how many values meet a condition
# - Write a loop that sums only the values meeting a condition
# - Recognize these patterns well enough to adapt them to a new problem
#
# </div>
#
# <style>
# .lesson-wrap { font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; color:#1e293b; line-height:1.65; }
# .lesson-wrap h2 { color:#0f172a; border-bottom:2px solid #e2e8f0; padding-bottom:6px; margin-top:1.8em; }
# .lesson-wrap h3 { color:#1e293b; margin-top:1.4em; }
# .callout { border-radius:10px; padding:16px 20px; margin:16px 0; border:1px solid #e2e8f0; background:#f8fafc; }
# .callout-objectives { background:#eff6ff; border-left:4px solid #2563eb; }
# .callout-objectives h4 { color:#1d4ed8; margin:0 0 8px 0; }
# .callout-hint { background:#fefce8; border-left:4px solid #ca8a04; }
# .callout-hint h4 { color:#a16207; margin:0 0 8px 0; }
# .callout-practice { background:#f0fdf4; border-left:4px solid #16a34a; }
# .callout-practice h4 { color:#15803d; margin:0 0 8px 0; }
# .callout-homework { background:#fdf4ff; border-left:4px solid #9333ea; }
# .callout-homework h4 { color:#7e22ce; margin:0 0 8px 0; }
# .callout-note { background:#f1f5f9; border-left:4px solid #64748b; }
# .callout-note h4 { color:#334155; margin:0 0 8px 0; }
# table { border-collapse:collapse; width:100%; margin:16px 0; }
# th, td { border:1px solid #e2e8f0; padding:10px 14px; text-align:left; }
# th { background:#f1f5f9; color:#0f172a; }
# details { border:1px solid #e2e8f0; border-radius:8px; padding:10px 16px; margin:12px 0; background:#fafafa; }
# details summary { cursor:pointer; font-weight:600; color:#2563eb; }
# details[open] summary { margin-bottom:10px; }
# .btn { display:inline-block; padding:10px 22px; border-radius:8px; border:none; font-weight:600; cursor:pointer; font-size:14px; transition:background .2s,transform .2s; }
# .btn-primary { background:#2563eb; color:#fff; }
# .btn-primary:hover { background:#1d4ed8; }
# .btn-secondary { background:#e2e8f0; color:#1e293b; }
# .btn-secondary:hover { background:#cbd5e1; }
# .pill { display:inline-block; padding:3px 12px; border-radius:999px; background:#eff6ff; color:#1d4ed8; font-size:0.85em; font-weight:600; margin-right:6px; }
# </style>
#
# <div class="lesson-wrap">
#
# These examples loop over an `ArrayList`, using just `.size()` and `.get(index)`. `ArrayList` gets its own full lesson in Unit 4, but a for loop that walks through one works exactly like the for loops you already know: initialize an index at 0, keep going while it's less than `.size()`, and increment.
#
# ## Standard Algorithm: Finding the Maximum
#
# ```java
# import java.util.ArrayList;
#
# public class FindMax {
#     public static void main(String[] args) {
#         ArrayList<Integer> scores = new ArrayList<Integer>();
#         scores.add(72);
#         scores.add(95);
#         scores.add(88);
#         scores.add(60);
#
#         int max = scores.get(0); // start with the first value, not 0
#
#         for (int i = 1; i < scores.size(); i++) {
#             if (scores.get(i) > max) {
#                 max = scores.get(i);
#             }
#         }
#
#         System.out.println("Max: " + max);
#     }
# }
# FindMax.main(null);
# ```

# %% [markdown]
# <div class="callout callout-hint">
# <h4>Common Mistake: Starting max at 0</h4>
#
# Starting `max` at `0` seems harmless until every value in the list is negative, in which case `0` is bigger than all of them and the algorithm reports a wrong maximum that was never even in the list. Always start `max` (or `min`) at the first actual element, then loop starting from index `1` so you don't compare it against itself.
#
# </div>
#
# ## Standard Algorithm: Counting Matches
#
# ```java
# import java.util.ArrayList;
#
# public class CountPassing {
#     public static void main(String[] args) {
#         ArrayList<Integer> scores = new ArrayList<Integer>();
#         scores.add(72);
#         scores.add(95);
#         scores.add(58);
#         scores.add(60);
#         scores.add(88);
#
#         int count = 0;
#         for (int i = 0; i < scores.size(); i++) {
#             if (scores.get(i) >= 60) {
#                 count++;
#             }
#         }
#
#         System.out.println("Passing scores: " + count);
#     }
# }
# CountPassing.main(null);
# ```
#
# The pattern is: a counter variable starting at 0, a loop over every element, and an if statement that increments the counter only when the condition is met.
#
# ## Standard Algorithm: Conditional Sum
#
# Summing works the same way, just adding the value itself instead of adding 1 to a counter:
#
# ```java
# import java.util.ArrayList;
#
# public class SumPassing {
#     public static void main(String[] args) {
#         ArrayList<Integer> scores = new ArrayList<Integer>();
#         scores.add(72);
#         scores.add(95);
#         scores.add(58);
#         scores.add(60);
#         scores.add(88);
#
#         int total = 0;
#         for (int i = 0; i < scores.size(); i++) {
#             if (scores.get(i) >= 60) {
#                 total += scores.get(i);
#             }
#         }
#
#         System.out.println("Total of passing scores: " + total);
#     }
# }
# SumPassing.main(null);
# ```
#
# All three algorithms share the same skeleton: set up a starting value before the loop, walk through every element once, and use an if statement inside the loop to decide whether that element affects the running result.
#
# <div class="callout callout-practice">
# <h4>Popcorn Hack</h4>
#
# Using the counting pattern above as a starting point, write a loop that counts how many scores in the list are below 60 instead of at or above it.
#
# </div>
#
# <div class="callout callout-homework">
# <h4>Homework Hack</h4>
#
# Write a `FindMin` class that finds the minimum value in an `ArrayList<Integer>`, following the same pattern as `FindMax` above. Test it with a list that includes at least one negative number, to confirm your starting value logic handles it correctly.
#
# </div>
#
# These three patterns, finding an extreme value, counting matches, and summing matches, cover most of what "implementing an algorithm" means in this course. The next lesson applies the exact same ideas to searching inside a String.
