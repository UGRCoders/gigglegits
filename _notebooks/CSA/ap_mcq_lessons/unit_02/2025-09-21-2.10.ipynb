# %% [markdown]
# ---
# layout: post
# toc: true
# title: Implementing String Algorithms
# menu: nav/csa_units/csaunit2.html
# permalink: /csa/unit_02/2_10
# ---

# %% [markdown]
# # Developing Algorithms Using Strings
#
# This lesson looks at standard algorithms for working with `String` objects, including how to search for a substring using a sliding window.
#
# <div class="callout callout-objectives">
# <h4>Objectives</h4>
#
# - Identify standard algorithms that operate on String objects
# - Use substring, equals, and length to work with parts of a string
# - Trace a window based substring search algorithm
# - Modify a standard algorithm to solve a related problem
#
# </div>
#
# <style>
# .lesson-wrap { font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; color:#1e293b; line-height:1.65; }
# .lesson-wrap h2 { color:#0f172a; border-bottom:2px solid #e2e8f0; padding-bottom:6px; margin-top:1.8em; }
# .lesson-wrap h3 { color:#1e293b; margin-top:1.4em; }
# .callout { border-radius:10px; padding:16px 20px; margin:16px 0; border:1px solid #e2e8f0; background:#f8fafc; }
# .callout-objectives { background:#eff6ff; border-left:4px solid #2563eb; }
# .callout-objectives h4 { color:#1d4ed8; margin:0 0 8px 0; }
# .callout-hint { background:#fefce8; border-left:4px solid #ca8a04; }
# .callout-hint h4 { color:#a16207; margin:0 0 8px 0; }
# .callout-practice { background:#f0fdf4; border-left:4px solid #16a34a; }
# .callout-practice h4 { color:#15803d; margin:0 0 8px 0; }
# .callout-homework { background:#fdf4ff; border-left:4px solid #9333ea; }
# .callout-homework h4 { color:#7e22ce; margin:0 0 8px 0; }
# .callout-note { background:#f1f5f9; border-left:4px solid #64748b; }
# .callout-note h4 { color:#334155; margin:0 0 8px 0; }
# table { border-collapse:collapse; width:100%; margin:16px 0; }
# th, td { border:1px solid #e2e8f0; padding:10px 14px; text-align:left; }
# th { background:#f1f5f9; color:#0f172a; }
# details { border:1px solid #e2e8f0; border-radius:8px; padding:10px 16px; margin:12px 0; background:#fafafa; }
# details summary { cursor:pointer; font-weight:600; color:#2563eb; }
# details[open] summary { margin-bottom:10px; }
# .btn { display:inline-block; padding:10px 22px; border-radius:8px; border:none; font-weight:600; cursor:pointer; font-size:14px; transition:background .2s,transform .2s; }
# .btn-primary { background:#2563eb; color:#fff; }
# .btn-primary:hover { background:#1d4ed8; }
# .btn-secondary { background:#e2e8f0; color:#1e293b; }
# .btn-secondary:hover { background:#cbd5e1; }
# .pill { display:inline-block; padding:3px 12px; border-radius:999px; background:#eff6ff; color:#1d4ed8; font-size:0.85em; font-weight:600; margin-right:6px; }
# </style>
#
# <div class="lesson-wrap">

# %% [markdown]
# Java has many methods that are helpful when working with strings:
#
# | Method | Purpose |
# |---|---|
# | `String.substring` | retrieves a portion of a string |
# | `String.equals` | compares two strings |
# | `String.length` | returns the length of a string |
# | `for` loop | iterates through the characters of a string |
#
# ### Finding a Substring Within a String
#
# We can use the window method: a window is created the same length as the substring. We then iterate through the main string in sections and compare each section to the substring.
#
# For example, searching for the substring "ERA" inside "ITERATE":

# %%
public class StringFinder {
    public static void main(String[] args) {
        String word = "iterate";
        String sub = "xxx";
        boolean found = false; // will be set to true once substring is found

        for (int i = 0; i < word.length(); i++) { //iterating forwards: starting at first index (0) and going to the length of the word.. let's try word.length
            String portion = word.substring(i, i + sub.length());
            if (sub.length() > portion.length()) break;
            if (portion.equals(sub)) { // make sure you use .equals!!
                found = true;
                break;
            }
        }

        if (found)
            System.out.println("substring is found within string!");
        else
            System.out.println("substring is NOT within string");
    }

}


StringFinder.main(null);

# %% [markdown]
# <div class="callout callout-practice">
# <h4>Popcorn Hack</h4>
#
# Run the code above. What happened, and how can we fix it?
#
# </div>
#
# ### Another Issue
#
# What if our substring was the word "RATE" instead? Note that "RATE" is at the end of the whole string "ITERATE".
#
# <div class="callout callout-homework">
# <h4>Hacks</h4>
#
# Create an algorithm similar to the one above. This time, use iteration to count the number of vowels within the main string.
#
# </div>
#
# <div class="callout callout-hint">
# <h4>Hint</h4>
#
# Use the boolean expressions you have learned in previous lessons. Which one would you use when comparing your window against multiple possible substrings?
#
# </div>
