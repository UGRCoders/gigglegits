# %% [markdown]
# ---
# layout: post
# toc: true
# title: Wrapper Classes
# menu: nav/csa_units/csaunit4.html
# permalink: /csa/unit_04/4_7
# ---

# %% [markdown]
# # Wrapper Classes
#
# The last lesson used `Integer.parseInt()` to turn a `String` from a file into an `int`. `Integer` is not a primitive type, it's a class, and it exists specifically to make a primitive value behave like an object. This lesson covers why that's necessary, and it directly sets up the next lesson, since ArrayLists can only hold objects.
#
# <div class="callout callout-objectives">
# <h4>Objectives</h4>
#
# - Match each primitive type to its wrapper class
# - Explain why ArrayList requires a wrapper class instead of a primitive type
# - Distinguish autoboxing and unboxing, and identify where Java performs them automatically
# - Convert between `String` and numeric types using wrapper class methods
#
# </div>
#
# <style>
# .lesson-wrap { font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; color:#1e293b; line-height:1.65; }
# .lesson-wrap h2 { color:#0f172a; border-bottom:2px solid #e2e8f0; padding-bottom:6px; margin-top:1.8em; }
# .lesson-wrap h3 { color:#1e293b; margin-top:1.4em; }
# .callout { border-radius:10px; padding:16px 20px; margin:16px 0; border:1px solid #e2e8f0; background:#f8fafc; }
# .callout-objectives { background:#eff6ff; border-left:4px solid #2563eb; }
# .callout-objectives h4 { color:#1d4ed8; margin:0 0 8px 0; }
# .callout-hint { background:#fefce8; border-left:4px solid #ca8a04; }
# .callout-hint h4 { color:#a16207; margin:0 0 8px 0; }
# .callout-practice { background:#f0fdf4; border-left:4px solid #16a34a; }
# .callout-practice h4 { color:#15803d; margin:0 0 8px 0; }
# .callout-homework { background:#fdf4ff; border-left:4px solid #9333ea; }
# .callout-homework h4 { color:#7e22ce; margin:0 0 8px 0; }
# .callout-note { background:#f1f5f9; border-left:4px solid #64748b; }
# .callout-note h4 { color:#334155; margin:0 0 8px 0; }
# table { border-collapse:collapse; width:100%; margin:16px 0; }
# th, td { border:1px solid #e2e8f0; padding:10px 14px; text-align:left; }
# th { background:#f1f5f9; color:#0f172a; }
# details { border:1px solid #e2e8f0; border-radius:8px; padding:10px 16px; margin:12px 0; background:#fafafa; }
# details summary { cursor:pointer; font-weight:600; color:#2563eb; }
# details[open] summary { margin-bottom:10px; }
# .btn { display:inline-block; padding:10px 22px; border-radius:8px; border:none; font-weight:600; cursor:pointer; font-size:14px; transition:background .2s,transform .2s; }
# .btn-primary { background:#2563eb; color:#fff; }
# .btn-primary:hover { background:#1d4ed8; }
# .btn-secondary { background:#e2e8f0; color:#1e293b; }
# .btn-secondary:hover { background:#cbd5e1; }
# .pill { display:inline-block; padding:3px 12px; border-radius:999px; background:#eff6ff; color:#1d4ed8; font-size:0.85em; font-weight:600; margin-right:6px; }
# </style>
#
# ## Why Primitives Need a Wrapper
#
# Every primitive type has a corresponding wrapper class, a full class that stores the same value but as an object:
#
# | Primitive | Wrapper Class |
# | --- | --- |
# | `int` | `Integer` |
# | `double` | `Double` |
# | `char` | `Character` |
# | `boolean` | `Boolean` |
# | `long` | `Long` |
#
# The reason this matters: Java's generic classes, including `ArrayList<E>`, only work with object types. `ArrayList<int>` is not legal Java, it's a compile error. `ArrayList<Integer>` is. Every `ArrayList<Integer>` you wrote in the last two lessons was only possible because `Integer` is a class, not a primitive.

# %% [markdown]
# ## Autoboxing and Unboxing
#
# You've actually been using wrapper classes without writing any conversion code yourself. That's because Java automatically converts between a primitive and its wrapper whenever the context calls for it.
#
# ```java
# import java.util.ArrayList;
#
# public class BoxingExample {
#     public static void main(String[] args) {
#         ArrayList<Integer> numbers = new ArrayList<>();
#
#         numbers.add(5);          // autoboxing: int 5 becomes Integer.valueOf(5)
#         int first = numbers.get(0); // unboxing: Integer becomes int automatically
#
#         System.out.println(first + 1); // 6, ordinary int math works fine after unboxing
#     }
# }
# ```
#
# - **Autoboxing** is Java automatically wrapping a primitive value in its wrapper class, `numbers.add(5)` compiles even though `add` expects an `Integer`, because Java converts the `int` for you.
# - **Unboxing** is the reverse: converting a wrapper object back to a primitive, so you can use it in ordinary arithmetic.
#
# This happens constantly with ArrayLists of numeric types, and it's why `ArrayList<Integer>` feels like it "just works" like an array of `int`, even though under the hood it's storing full `Integer` objects.
#
# <div class="callout callout-hint">
# <h4>Attention: Common Mistake</h4>
#
# Wrapper objects are objects, which means `==` compares references, not values, the same rule as any other object. `Integer a = 200; Integer b = 200; a == b` can print `false`, because `a` and `b` may be two separate `Integer` objects holding the same value. Always use `.equals()` to compare wrapper values, or unbox to a primitive first, exactly like the `.equals()` rule you already know for `String` and other objects.
#
# </div>
#
# ## Converting Between Strings and Numbers
#
# Wrapper classes also provide static methods for converting text to numbers and back, which is exactly what you needed last lesson to turn a line read from a file into a usable number.
#
# ```java
# public class ConversionExample {
#     public static void main(String[] args) {
#         String line = "42";
#         int value = Integer.parseInt(line);   // String to int
#         System.out.println(value + 8);        // 50
#
#         double price = Double.parseDouble("19.99"); // String to double
#         System.out.println(price);
#
#         int score = 91;
#         String asText = Integer.toString(score); // int to String
#         System.out.println("Score: " + asText);
#     }
# }
# ConversionExample.main(null)
# ```
#
# <div class="callout callout-practice">
# <h4>Popcorn Hack</h4>
#
# Predict the output, then check it: what does `Integer.parseInt("7") + Integer.parseInt("3")` evaluate to, and how is that different from `"7" + "3"`?
#
# <details>
# <summary>Show answer</summary>
#
# `Integer.parseInt("7") + Integer.parseInt("3")` is `10`, because both values are converted to `int` before the `+`. `"7" + "3"` is `"73"`, because `+` between two `String`s concatenates instead of adding.
#
# </details>
#
# </div>
#
# <div class="callout callout-homework">
# <h4>Homework Hack</h4>
#
# Write a program that starts with a `String` array of numbers as text, for example `{"12", "45", "7", "23"}`, converts each one to an `int`, and prints their sum and their average. Then explain in a sentence why you couldn't just add the `String` elements directly with `+`.
#
# </div>
