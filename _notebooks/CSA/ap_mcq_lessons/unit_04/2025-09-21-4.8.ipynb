# %% [markdown]
# ---
# layout: post
# toc: true
# title: ArrayList Methods
# menu: nav/csa_units/csaunit4.html
# permalink: /csa/unit_04/4_8
# ---

# %% [markdown]
# # ArrayList Methods
#
# This lesson introduces Java's `ArrayList` class: how it compares to an array, and the core methods you use to build, read, and modify one.
#
# <div class="callout callout-objectives">
# <h4>Objectives</h4>
#
# - Explain how an ArrayList differs from an array and when to use each
# - Import and declare a generic ArrayList with `ArrayList<E>`
# - Use the core ArrayList methods: size, add, get, set, and remove
# - Explain why ArrayList is preferred over a raw ArrayList as a parameter type, and when a raw ArrayList is acceptable
#
# </div>
#
# <style>
# .lesson-wrap { font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; color:#1e293b; line-height:1.65; }
# .lesson-wrap h2 { color:#0f172a; border-bottom:2px solid #e2e8f0; padding-bottom:6px; margin-top:1.8em; }
# .lesson-wrap h3 { color:#1e293b; margin-top:1.4em; }
# .callout { border-radius:10px; padding:16px 20px; margin:16px 0; border:1px solid #e2e8f0; background:#f8fafc; }
# .callout-objectives { background:#eff6ff; border-left:4px solid #2563eb; }
# .callout-objectives h4 { color:#1d4ed8; margin:0 0 8px 0; }
# .callout-hint { background:#fefce8; border-left:4px solid #ca8a04; }
# .callout-hint h4 { color:#a16207; margin:0 0 8px 0; }
# .callout-practice { background:#f0fdf4; border-left:4px solid #16a34a; }
# .callout-practice h4 { color:#15803d; margin:0 0 8px 0; }
# .callout-homework { background:#fdf4ff; border-left:4px solid #9333ea; }
# .callout-homework h4 { color:#7e22ce; margin:0 0 8px 0; }
# .callout-note { background:#f1f5f9; border-left:4px solid #64748b; }
# .callout-note h4 { color:#334155; margin:0 0 8px 0; }
# table { border-collapse:collapse; width:100%; margin:16px 0; }
# th, td { border:1px solid #e2e8f0; padding:10px 14px; text-align:left; }
# th { background:#f1f5f9; color:#0f172a; }
# details { border:1px solid #e2e8f0; border-radius:8px; padding:10px 16px; margin:12px 0; background:#fafafa; }
# details summary { cursor:pointer; font-weight:600; color:#2563eb; }
# details[open] summary { margin-bottom:10px; }
# .btn { display:inline-block; padding:10px 22px; border-radius:8px; border:none; font-weight:600; cursor:pointer; font-size:14px; transition:background .2s,transform .2s; }
# .btn-primary { background:#2563eb; color:#fff; }
# .btn-primary:hover { background:#1d4ed8; }
# .btn-secondary { background:#e2e8f0; color:#1e293b; }
# .btn-secondary:hover { background:#cbd5e1; }
# .pill { display:inline-block; padding:3px 12px; border-radius:999px; background:#eff6ff; color:#1d4ed8; font-size:0.85em; font-weight:600; margin-right:6px; }
# </style>
#
# ## ArrayList Intro
#
# - ArrayLists are dynamic: their size can grow or shrink as needed. Arrays are static: their size is fixed the moment they're created.
# - Instead of creating a new, bigger array and copying every element over when you run out of room, an ArrayList handles resizing for you.
#
# | Arrays | ArrayLists |
# | --- | --- |
# | Fixed length | Resizable length |
# | Fundamental Java feature | Part of the `java.util` framework |
# | No methods, just `.length` | Class with many built-in methods |
# | Can store primitive data | Cannot store primitives directly (needs wrapper classes, see 4.7) |
# | Slightly faster | Slightly slower than arrays |
# | No import needed | Needs `import java.util.ArrayList;` |
#
# ```java
# import java.util.ArrayList;
#
# // Declare and initialize an ArrayList of integers
# ArrayList<Integer> numbersList = new ArrayList<>();
# ```
#
# ArrayList objects are created like any other object, except you specify the type of element the list will hold using angle brackets `<>`. In the general form below, `E` stands for whatever element type you choose:
#
# ```java
# ArrayList<E> list = new ArrayList<E>();
# ```
#
# You can technically declare an ArrayList without specifying `E`, but you shouldn't. Specifying the type lets the compiler catch type mismatches before your code ever runs, instead of crashing later.
#
# ```java
# ArrayList list = new ArrayList(); // legal, but avoid this
# ```

# %% [markdown]
# <div class="callout callout-practice">
# <h4>Popcorn Hack</h4>
#
# Create 2 ArrayLists, 1 called `studentName` and 1 called `studentAge`.
#
# ```java
# public class Student
# {
#     public static void main(String[] args)
#     {
#         //Initialize your ArrayLists
#
#     }
# }
# ```
#
# </div>

# %% [markdown]
# ## ArrayList Methods
#
# Iteration statements let you access every element stored in an `ArrayList`; this is called traversing the ArrayList, and it's covered in depth in the next lesson. First, here are the core methods every ArrayList supports. These are part of the AP CSA Java Quick Reference, so it's worth knowing them cold:
#
# | Method | What it does |
# | --- | --- |
# | `int size()` | Returns the number of elements in the list. |
# | `boolean add(E obj)` | Appends `obj` to the end of the list, returns true. |
# | `void add(int index, E obj)` | Inserts `obj` at `index`, shifting everything at and after that position one spot to the right. |
# | `E get(int index)` | Returns the element at `index`. |
# | `E set(int index, E obj)` | Replaces the element at `index` with `obj`, returns the old element. |
# | `E remove(int index)` | Removes the element at `index`, shifting everything after it one spot to the left, returns the removed element. |
#
# `ArrayList<E>` is a generic class: whatever type you plug in for `E` is what `get`, `set`, and `add` will accept and return. Using `ArrayList<E>` instead of a raw `ArrayList` lets the compiler catch type mistakes at compile time instead of at runtime.
#
# ### Size
#
# ```java
# ArrayList<Integer> a1 = new ArrayList<>();
# System.out.println(a1.size()); // 0, a new ArrayList starts empty
# ```
#
# ### Adding Items
#
# ```java
# ArrayList<Double> a2 = new ArrayList<>();
# a2.add(1.0);
# a2.add(2.0);
# a2.add(3.0);      // a2 is now [1.0, 2.0, 3.0]
# a2.add(1, 4.0);   // insert 4.0 at index 1, shifting the rest right
# System.out.println(a2); // [1.0, 4.0, 2.0, 3.0]
# ```
#
# ### Removing Items
#
# ```java
# ArrayList<String> g = new ArrayList<>();
# g.add("Hello");
# g.add("Hola");
# g.add("HeLLO");
# g.add("Bonjour");
#
# g.remove(3);              // removes "Bonjour"
# String former = g.remove(0); // removes and returns "Hello"
# System.out.println(former);  // Hello
# System.out.println(g);       // [Hola, HeLLO]
# ```
#
# ### Updating and Accessing Items
#
# ```java
# String helloFormer = g.set(0, "Ciao"); // replaces index 0, returns the old value
# System.out.println(helloFormer); // Hola
# System.out.println(g);           // [Ciao, HeLLO]
#
# String hello = g.get(1);
# System.out.println(hello); // HeLLO
# ```
#
# ### Passing an ArrayList as a Parameter
#
# The one time it's acceptable to use a raw `ArrayList` instead of `ArrayList<E>` is as a method parameter, and only if the method body just calls `.size()` and `.get(index)` without caring about the specific type:
#
# ```java
# private void accessOnly(ArrayList arr) {
#     if (arr.size() > 0) {
#         System.out.println(arr.get(0));
#     } else {
#         System.out.println("Array is empty");
#     }
# }
#
# ArrayList<Integer> myList = new ArrayList<Integer>();
# accessOnly(myList);
# ```
#
# ### Returning an ArrayList from a Method
#
# The return type has to match the ArrayList's declared type:
#
# ```java
# private ArrayList<String> returnTheSame() {
#     ArrayList<String> arr = new ArrayList<String>();
#     arr.add("Hello");
#     return arr;
# }
#
# ArrayList<String> result = returnTheSame();
# System.out.println(result); // [Hello]
# ```

# %% [markdown]
# <div class="callout callout-homework">
# <h4>Homework Hack</h4>
#
# - Look back at Size. What does the code output, and why?
# - Look back at Adding Items. What is the return type of `void add(int, E)`? Why doesn't it return anything, unlike `boolean add(E)`?
# - If an ArrayList is being used as a parameter of the raw type `ArrayList` (no `<E>`), what methods can you safely call on it? What would happen if you tried to use `add` with the wrong type?
# - Using the Hack Helper below, write code that will:
#     * Add 2 items to the list.
#     * Remove an item from the list, at an index of your choice.
#     * Replace an item anywhere in the list.
#     * Get the first and last element of the list, no matter its length.
#     * Return the items added, removed, and replaced, plus the list's final size, in one string.
#
# ### Hack Helper
#
# ```java
# public class ArrayListMethodsExample {
#     private String manipulateList() {
#         // Your code here
#         return "";
#     }
#
#     public static void main(String[] args) {
#         ArrayListMethodsExample example = new ArrayListMethodsExample();
#         String output = example.manipulateList();
#         System.out.println(output);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div class="callout callout-note">
# <h4>Grading</h4>
#
# - Popcorn Hack: introducing ArrayLists (0.3)
# - Homework Hack: ArrayList methods (0.6)
# - Anything creative or above and beyond showing your understanding of ArrayList methods (0.1)
#
# </div>
#
# Once you're comfortable creating an ArrayList and calling its core methods, the next lesson covers how to traverse one, visiting every element in order the same way you traversed arrays in Unit 4.
